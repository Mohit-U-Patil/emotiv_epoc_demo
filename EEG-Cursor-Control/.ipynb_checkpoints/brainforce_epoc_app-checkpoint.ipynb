# %%
import json
import ssl
from websocket import create_connection
import time
import pyautogui
import math

# %%
receivedData = create_connection("wss://localhost:6868", sslopt={"cert_reqs": ssl.CERT_NONE})

# %%
receivedData.send(json.dumps({"id":1,"jsonrpc":"2.0","method":"getCortexInfo"}))
print(receivedData.recv())
# Out:
# {"id":1,"jsonrpc":"2.0","result":{"buildDate":"2020-07-08T15:04:40","buildNumber":"v2.2.3-489-g144c66b","version":"2.5.2.65"}}

# %%
receivedData.send(json.dumps({
    "id": 1,
    "jsonrpc": "2.0",
    "method": "requestAccess",
    "params": { "clientId" : 'D8sPj2gQQj5jZ1moNhixWFAC3wsWvpoaA5Bl05cX', "clientSecret" : "HDiYXZIMsdGWs1iiHIvGm7ajx4YIQaEfjDrI7ApcPXDHEQQnl1TSLoJBhN4358DZdaEZrjoqZwObFwji687jVI67SgQkXxc8SxUILTB8aMiLN2ohwOIAjW2sdI4S7wIz"
}
}))
print(receivedData.recv())
# Out:
# {"id":1,"jsonrpc":"2.0","result":{"accessGranted":true,"message":"The user has granted access right to this application."}}

# %%
receivedData.send(json.dumps({"id": 1,
    "jsonrpc": "2.0",
    "method": "authorize",
    "params": { "clientId" : 'D8sPj2gQQj5jZ1moNhixWFAC3wsWvpoaA5Bl05cX', "clientSecret" : "HDiYXZIMsdGWs1iiHIvGm7ajx4YIQaEfjDrI7ApcPXDHEQQnl1TSLoJBhN4358DZdaEZrjoqZwObFwji687jVI67SgQkXxc8SxUILTB8aMiLN2ohwOIAjW2sdI4S7wIz"
},
}))

# print(receivedData.recv())

token = json.loads(receivedData.recv())['result']['cortexToken']

print(token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhcHBJZCI6ImNvbS5tb2hpdDMubW9oaXRfcGF0aWxfYXBwMSIsImFwcFZlcnNpb24iOiIxLjAiLCJleHAiOjE1OTUwMzYyMTAsIm5iZiI6MTU5NDc3NzAxMCwidXNlcklkIjoiOWFmNjc0ZGMtNGMyMC00NjNkLTkxYTQtMzk0M2ZmNjA5N2RkIiwidXNlcm5hbWUiOiJtb2hpdDMiLCJ2ZXJzaW9uIjoiMi4wIn0=.oIFEmz2yFiKzD2SLOj3izYiLDSUHY04hn8ivvT+gX5I=

# %%
#get new token in case old one expires. 2 days expiry if hasn't been extended
# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "generateNewToken",
#     "params": {
#         "cortexToken": token,
#         "clientId": "D8sPj2gQQj5jZ1moNhixWFAC3wsWvpoaA5Bl05cX",
#         "clientSecret": "HDiYXZIMsdGWs1iiHIvGm7ajx4YIQaEfjDrI7ApcPXDHEQQnl1TSLoJBhN4358DZdaEZrjoqZwObFwji687jVI67SgQkXxc8SxUILTB8aMiLN2ohwOIAjW2sdI4S7wIz"
#     }
# }))
# token = json.loads(receivedData.recv())['result']['cortexToken']

# %%
#from the file= Client
print("\nHeadset Query...")

receivedData.send(json.dumps({
    "jsonrpc": "2.0",
    "method": "queryHeadsets",
    "params": {},
    "id": 1
}))

print(receivedData.recv())
# Out:
# Headset Query...
# {"id":1,"jsonrpc":"2.0","result":[{"connectedBy":"dongle","customName":"","dongle":"6ff","firmware":"633","headbandPosition":null,"id":"EPOCPLUS-4A2C110A","isDfuMode":false,"isVirtual":false,"motionSensors":["Q0","Q1","Q2","Q3","ACCX","ACCY","ACCZ","MAGX","MAGY","MAGZ"],"sensors":["AF3","F7","F3","FC5","T7","P7","O1","O2","P8","T8","FC6","F4","F8","AF4"],"settings":{"eegRate":128,"eegRes":16,"memsRate":32,"memsRes":16,"mode":"EPOCPLUS"},"status":"connected","virtualHeadsetId":""}]}

# %%
receivedData.send(json.dumps({
    "id": 1,
    "jsonrpc": "2.0",
    "method": "querySessions",
    "params": {
        "cortexToken": token
    }
}))
querySessions = receivedData.recv()

# %%
querySessions
# Out:
# '{"id":1,"jsonrpc":"2.0","result":[]}'

# %%
print("\nCreating session...")
#new cortex method to open the session. We don't activate the session yet. Use this after checking if last session id is still
# active, next cell querySession does that.
receivedData.send(json.dumps({
    "id": 1,
    "jsonrpc": "2.0",
    "method": "createSession",
    "params": {
        "cortexToken": token,
        "headset": "EPOCPLUS-4A2C110A",
        "status": "open"
    }
}))
session = json.loads(receivedData.recv())
# Out:
# Creating session...

# %%
print(session)
session_id = session['result']['id']
print(session_id)
# Out:
# {'id': 1, 'jsonrpc': '2.0', 'result': {'appId': 'com.mohit3.mohit_patil_app1', 'headset': {'connectedBy': 'dongle', 'dongle': '6ff', 'firmware': '633', 'id': 'EPOCPLUS-4A2C110A', 'isDfuMode': False, 'isVirtual': False, 'motionSensors': ['Q0', 'Q1', 'Q2', 'Q3', 'ACCX', 'ACCY', 'ACCZ', 'MAGX', 'MAGY', 'MAGZ'], 'sensors': ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4'], 'settings': {'eegRate': 128, 'eegRes': 16, 'memsRate': 32, 'memsRes': 16, 'mode': 'EPOCPLUS'}, 'status': 'connected', 'virtualHeadsetId': ''}, 'id': '2a052fc7-4a2c-41b4-825b-c50415bbc74e', 'license': '', 'owner': 'mohit3', 'performanceMetrics': [{'apiName': 'auditoryAttention', 'displayedName': '', 'name': 'auditoryAttention', 'shortDisplayedName': ''}, {'apiName': 'visualAttention', 'displayedName': '', 'name': 'visualAttention', 'shortDisplayedName': ''}, {'apiName': 'cognitiveStress', 'displayedName': '', 'name': 'cognitiveStress', 'shortDisplayedName': ''}, {'apiName': 'eng', 'displayedName': 'Engagement', 'name': 'engagement', 'shortDisplayedName': 'En'}, {'apiName': 'exc', 'displayedName': 'Excitement', 'name': 'excitement', 'shortDisplayedName': 'Ex'}, {'apiName': 'str', 'displayedName': 'Stress', 'name': 'stress', 'shortDisplayedName': 'St'}, {'apiName': 'rel', 'displayedName': 'Relaxation', 'name': 'relaxation', 'shortDisplayedName': 'Re'}, {'apiName': 'int', 'displayedName': 'Interest', 'name': 'interest', 'shortDisplayedName': 'In'}, {'apiName': 'foc', 'displayedName': 'Focus', 'name': 'focus', 'shortDisplayedName': 'Fo'}], 'recordIds': [], 'recording': False, 'started': '2020-07-15T21:36:51.106-04:00', 'status': 'opened', 'stopped': '', 'streams': []}}
# 2a052fc7-4a2c-41b4-825b-c50415bbc74e

# %%
# print("\nSubscribing to session...")
# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "subscribe",
#     "params": {
#         "cortexToken": token,
#         "session": session_id,
#         "streams": ["sys"]
#     }
# }))

# %%
# print(receivedData.recv())

# %%
# print("\nGetting detection info...")

# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "getDetectionInfo",
#     "params": {
#         "detection": "mentalCommand"
#     }
# }))

# print(receivedData.recv())

# %%
#trial block for loading a training profile
# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "queryProfile",
#     "params": {
#         "cortexToken": token
#     }
# }))
# queryProfile = receivedData.recv()

# %%
# queryProfile

# %%
# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "getCurrentProfile",
#     "params": {
#         "cortexToken": token,
#         "headset": "EPOCPLUS-4A2C110A"
#     }
# }))
# currentProfile = receivedData.recv()

# %%
# currentProfile

# %%
# setting up a profile. This is trial here. A trained profile from the emotiv app is loaded in the while loop below
# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "setupProfile",
#     "params": {
#         "cortexToken": token,
#         "headset": "EPOCPLUS-4A2C110A",
#         "profile": "mopatesting",
#         "status": "load"
#     }
# }))
# setupProfile = receivedData.recv()

# %%
# setupProfile

# %% [raw]
# def train_command(request):
#     print("Training " + request + " command...")
#     receivedData.send(json.dumps( {
#      "jsonrpc": "2.0",
#      "method": "training",
#      "params": {
#        "cortexToken":token,
#        "detection":"mentalCommand",
#         "session": session_id,
#        "action":request,
#        "status":"start"
#      },
#      "id": 1
#      }))
#
#     print(receivedData.recv())
#     time.sleep(5)
#     print(receivedData.recv())
#     time.sleep(10)
#     print(receivedData.recv())
#
#     receivedData.send(json.dumps( {
#      "jsonrpc": "2.0",
#      "method": "training",
#      "params": {
#        "cortexToken":token,
#        "detection":"mentalCommand",
#         "session": session_id,
#        "action":request,
#        "status":"accept"
#      },
#      "id": 1
#      }
#     ))
#
#     print(receivedData.recv())
#     time.sleep(2)
#     print(receivedData.recv())

# %%
#trial cell for the main while loop below
# receivedData.send(json.dumps({
#     "id": 1,
#     "jsonrpc": "2.0",
#     "method": "getCurrentProfile",
#     "params": {
#         "cortexToken": token,
#         "headset": "EPOCPLUS-4A2C110A"
#     }
# }))
# print(receivedData.recv())

# %%
# while True:
#     while True:
#         try:
#             startCode = input('\n\nTo train commands, type "1". To begin the game, type "2"\n>>> ')
#             if startCode == "1" or startCode == "2":
#                 break
#             else:
#                 print("Invalid input")
#         except ValueError:
#             print("Invalid input")

#     if startCode == "1":
#         while True:
#             try:
                
#                 req = input("Which command would you like to train? (Neutral, Left, Right, Lift, Drop, Push)\n>>> ").lower()         

#                 if req == "neutral" or req == "lift" or req == "drop" or req == "left" or req == "right" or req == "push":
#                     train_command(req)
#                     break
#                 else:
#                     print("Invalid input")
#             except:
#                 print("Invalid input")
                
#     elif startCode == "2":

#         print("Getting USER login...")

#         receivedData.send(json.dumps({
#             "jsonrpc": "2.0",
#             "method": "getUserLogin",
#             "id": 1
#         }))

#         profile = json.loads(receivedData.recv())["result"][0]
#         print(profile)
        
#         receivedData.send(json.dumps({
#             "id": 1,
#             "jsonrpc": "2.0",
#             "method": "subscribe",
#             "params": {
#                 "cortexToken": token,
#                 "session": session_id,
#                 "streams": ["com"]
#             }
#         }))
        

#         print("Subscription:", receivedData.recv())
        
# # This is if we want to create a new profile with training done here in the script.
# #         receivedData.send(json.dumps({
# #             "jsonrpc": "2.0",
# #             "method": "setupProfile",
# #             "params": {
# #                 "cortexToken": token,
# #                 "profile": profile,
# #                 "status": "create"
# #             },
# #             "id": 1
# #         }))
# #for creating the temporary guest profile without setting up a profile.
# #         {
# #             "id": 1,
# #             "jsonrpc": "2.0",
# #             "method": "loadGuestProfile",
# #             "params": {
# #                 "cortexToken": "xxx",
# #                 "headset": "INSIGHT-12341234"
# #             }
# #         }

# #Loading pretrained profile
#         receivedData.send(json.dumps({
#             "id": 1,
#             "jsonrpc": "2.0",
#             "method": "setupProfile",
#             "params": {
#                 "cortexToken": token,
#                 "headset": "EPOCPLUS-4A2C110A",
#                 "profile": "mopatesting",
#                 "status": "load"
#             }
#         }))
#         setupProfile = receivedData.recv()


#         print("Profile Set-up:", receivedData.recv())

#         receivedData.send(json.dumps({
#             "jsonrpc": "2.0",
#             "method": "mentalCommandBrainMap",
#             "params": {
#                 "cortexToken": token,
#                 "profile": "mopatesting"
#             },
#             "id": 1
#         }))

#         synapseData = receivedData.recv()

#         print("Mental Command Brain Map:", synapseData)

#         while True:
#             thought = json.loads(receivedData.recv())["com"][0]
#             print(thought)

#             maxX, maxY = pyautogui.size()

#             try:
#                 x, y = pyautogui.position()      
#             except KeyboardInterrupt:
#                 print('\n')

#             if thought == "left" and x>0:
#                 pyautogui.move(-4, None)
#             elif thought == "right" and x<maxX:
#                 pyautogui.move(4, None)
#             elif thought == "lift" and y<maxY:
#                 pyautogui.move(None, -4)
#             elif thought == "drop" and y>0:
#                 pyautogui.move(None, 4)
#             elif thought == "neutral":
#                 pyautogui.move(None, None)
#             elif thought == "push":
#                 pyautogui.click()

# %%
receivedData.send(json.dumps({
            "id": 1,
            "jsonrpc": "2.0",
            "method": "subscribe",
            "params": {
                "cortexToken": token,
                "session": session_id,
                "streams": ["mot"]
            }
        }))

print(receivedData.recv())
# Out:
# {"id":1,"jsonrpc":"2.0","result":{"failure":[],"success":[{"cols":["COUNTER_MEMS","INTERPOLATED_MEMS","Q0","Q1","Q2","Q3","ACCX","ACCY","ACCZ","MAGX","MAGY","MAGZ"],"sid":"2a052fc7-4a2c-41b4-825b-c50415bbc74e","streamName":"mot"}]}}

# %%
# receivedData.send(json.dumps({
#             "id": 1,
#             "jsonrpc": "2.0",
#             "method": "unsubscribe",
#             "params": {
#                 "cortexToken": token,
#                 "session": session_id,
#                 "streams": ["mot"]
#             }
#         }))
# print(receivedData.recv())

# %%
# gyro_mot = json.loads(receivedData.recv())["mot"]
# print(gyro_mot)

# %%
# epoc_quaternion = Quaternion(gyro_mot[2:6])
# epoc_quaternion
# numpy.set_printoptions(suppress=True) # Suppress insignificant values for clarity
# v = numpy.array([0., 0., 1.]) # Unit vector in the +z direction
# v_prime = epoc_quaternion.rotate(v)
# v_prime #rotated vector

# %%
#new updated quaternion each sample, vector is updated from the rotated vector
# from pyquaternion import Quaternion
# import numpy

# v = numpy.array([0., 0., 1.]) # Unit vector in the +z direction, initialize out of the loop
# v_old = v

# while True:
#     gyro_mot = json.loads(receivedData.recv())["mot"]
# #     print(gyro_mot)
#     if(gyro_mot[0] == 0):
#         epoc_quaternion = Quaternion(gyro_mot[2:6])
#         numpy.set_printoptions(suppress=True) # Suppress insignificant values for clarity
#         v_prime = epoc_quaternion.rotate(v)
#         shift_vec = v_prime - v_old
#         v_old = v_prime
#         print(v_prime) #rotated vector
#     #time.sleep(2)

# %%
def quattorotmat(q):
        q00,q10,q20,q30 = normalize(q)
        #trying to match axis to cube
        #this replacement matches axis properly with implementation  rot_mat = angletorotmat(-y_rot, -x_rot, -z_rot) 
        q0 = q00
        q1 = q30
        q2 = q10
        q3 = q20

        #trial block: convert quat to euler angle, make rotation matrix to verify
        
        y_rot = math.asin( 2*(q0*q2 - q1*q3) )
               
        if y_rot == numpy.pi/2:
            x_rot = 0
            z_rot = -2*math.atan2(q1,q0)
        elif y_rot == -numpy.pi/2:
            x_rot = 0
            z_rot = 2*math.atan2(q1,q0)
        else:
            x_rot = math.atan2( 2*(q0*q1 + q2*q3), q0**2 - q1**2 - q2**2 + q3**2 )
            z_rot = math.atan2( 2*(q0*q3 + q1*q2), q0**2 + q1**2 - q2**2 - q3**2 )
            
        return(x_rot, y_rot, z_rot)
    
#this function convertes given rotation angles into rotation matrix
def angletorotmat(ang_x, ang_y, ang_z):
    # import numpy as np
    # ang_x = ang_y = ang_z = np.pi/4
    r = R.from_euler('zyx', [ang_z, ang_y, ang_x], degrees=False)
    X = r.as_matrix()
    X0 = numpy.zeros((3,1))
    Xnew = numpy.hstack((X,X0))
    Xlast = numpy.array([0, 0, 0, 1] )
    Xfinal = numpy.vstack((Xnew,Xlast))        
    rot_mat_in = numpy.array(Xfinal,'f')
#     print(rot_mat_in)
    return(rot_mat_in)

def normalize(v, tolerance=0.00001):
    mag2 = sum(n * n for n in v)
    if abs(mag2 - 1.0) > tolerance:
        mag = numpy.sqrt(mag2)
        v = tuple(n / mag for n in v)
    return v

# %% [raw]
# #cursor control: use quaternion and then transform axis to the screen frame
# from pyquaternion import Quaternion
# import numpy as np
# from scipy.spatial.transform import Rotation as R
# # pyautogui.FAILSAFE = False
#
# v = np.array([0., 0., 1.]) # Unit vector in the +z direction, initialize out of the loop
# v_old = v
#
# def normalize(v, tolerance=0.00001):
#     mag2 = sum(n * n for n in v)
#     if abs(mag2 - 1.0) > tolerance:
#         mag = np.sqrt(mag2)
#         v = tuple(n / mag for n in v)
#     return v
#
# while True:
#     gyro_mot = json.loads(receivedData.recv())["mot"]
#
#     if(gyro_mot[0] == 0): # or gyro_mot[10] or gyro_mot[20] or gyro_mot[30]):
#
#         epoc_quaternion = Quaternion(gyro_mot[2:6])
#         numpy.set_printoptions(suppress=True) # Suppress insignificant values for clarity
#         v_prime = epoc_quaternion.rotate(v)
#         shift_vec = v_prime - v_old
#         v_old = v_prime
#     #     print(v_prime) #rotated vector
#
#         maxX, maxY = pyautogui.size()
#
#         try:
#             x, y = pyautogui.position()
#         except KeyboardInterrupt:
#             print('\n')
#
#         q0,q1,q2,q3 = normalize(gyro_mot[2:6])
#         y_rot = math.asin( 2*(q0*q2 - q1*q3) )
#
#
#         if y_rot == np.pi/2:
#             x_rot = 0
#             z_rot = -2*math.atan2(q1,q0)
#         elif y_rot == -np.pi/2:
#             x_rot = 0
#             z_rot = 2*math.atan2(q1,q0)
#         else:
#             x_rot = math.atan2( 2*(q0*q1 + q2*q3), q0**2 - q1**2 - q2**2 + q3**2 )
#             z_rot = math.atan2( 2*(q0*q3 + q1*q2), q0**2 + q1**2 - q2**2 - q3**2 )
#
#         y_mouse_rot = -z_rot
#         x_mouse_rot = -y_rot
#
#         x_shift = -(48/np.pi) * -x_mouse_rot
#         y_shift = -(7/np.pi) * -y_mouse_rot
# #         print(x_rot, y_rot)
# #         print(x_shift,y_shift)
#         pyautogui.moveRel(x_shift, y_shift, duration=0)

# %%
#cursor control: transform quaternion into the rot_mat and then use projections
from pyquaternion import Quaternion
import numpy
from scipy.spatial.transform import Rotation as R

pyautogui.MINIMUM_DURATION = 0.0
pyautogui.PAUSE = 0.0
pyautogui.MINIMUM_SLEEP = 0.0
pyautogui.FAILSAFE = False

v = numpy.array([0., 0., 1.,1]) # Unit vector in the +z direction, initialize out of the loop
it = 0

while True:
    gyro_mot = json.loads(receivedData.recv())["mot"]
    
    if True:#gyro_mot[0] == 0:
        it+=1
#         print(gyro_mot)
        maxX, maxY = pyautogui.size()

        try:
            x, y = pyautogui.position()      
        except KeyboardInterrupt:
            print('\n')

        x_rot, y_rot, z_rot = quattorotmat(gyro_mot[2:6])   
        # rot_mat = angletorotmat(-y_rot, -x_rot, -z_rot)            

        #cursor control with rotation
        scale_x = 6000/numpy.pi
        scale_y = 2000/numpy.pi
        x_shift_new = scale_x * y_rot
        y_shift_new = scale_y * x_rot
        
        if it == 1:
            x_shift = 0
            y_shift = 0
        else:
            x_shift = int(x_shift_new - x_shift_old)
            y_shift = int(y_shift_new - y_shift_old)
        
        y_shift_old = y_shift_new
        x_shift_old = x_shift_new
        
        #cursor control with vector projection
    #         v_out = numpy.matmul(rot_mat, v)
    #         x_shift = -v_out[1]
    #         y_shift = -v_out[0]

    #         print(x_rot, y_rot)
#         print(x_shift,y_shift)

        pyautogui.move(x_shift, y_shift)
#         print(gyro_mot)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-a9f9f569ce80> in <module>
#      13
#      14 while True:
# ---> 15     gyro_mot = json.loads(receivedData.recv())["mot"]
#      16
#      17     if gyro_mot[0] == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_core.py in recv(self)
#     312         """
#     313         with self.readlock:
# --> 314             opcode, data = self.recv_data()
#     315         if six.PY3 and opcode == ABNF.OPCODE_TEXT:
#     316             return data.decode("utf-8")
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_core.py in recv_data(self, control_frame)
#     329         return  value: tuple of operation code and string(byte array) value.
#     330         """
# --> 331         opcode, frame = self.recv_data_frame(control_frame)
#     332         return opcode, frame.data
#     333
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_core.py in recv_data_frame(self, control_frame)
#     342         """
#     343         while True:
# --> 344             frame = self.recv_frame()
#     345             if not frame:
#     346                 # handle error:
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_core.py in recv_frame(self)
#     376         return value: ABNF frame object.
#     377         """
# --> 378         return self.frame_buffer.recv_frame()
#     379
#     380     def send_close(self, status=STATUS_NORMAL, reason=six.b("")):
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_abnf.py in recv_frame(self)
#     359             # Header
#     360             if self.has_received_header():
# --> 361                 self.recv_header()
#     362             (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     363
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_abnf.py in recv_header(self)
#     307
#     308     def recv_header(self):
# --> 309         header = self.recv_strict(2)
#     310         b1 = header[0]
#     311
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_abnf.py in recv_strict(self, bufsize)
#     394             # buffers allocated and then shrunk, which results in
#     395             # fragmentation.
# --> 396             bytes_ = self.recv(min(16384, shortage))
#     397             self.recv_buffer.append(bytes_)
#     398             shortage -= len(bytes_)
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_core.py in _recv(self, bufsize)
#     451     def _recv(self, bufsize):
#     452         try:
# --> 453             return recv(self.sock, bufsize)
#     454         except WebSocketConnectionClosedException:
#     455             if self.sock:
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_socket.py in recv(sock, bufsize)
#     100             bytes_ = sock.recv(bufsize)
#     101         else:
# --> 102             bytes_ = _recv()
#     103     except socket.timeout as e:
#     104         message = extract_err_message(e)
#
# C:\ProgramData\Anaconda3\lib\site-packages\websocket\_socket.py in _recv()
#      82     def _recv():
#      83         try:
# ---> 84             return sock.recv(bufsize)
#      85         except SSLWantReadError:
#      86             pass
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv(self, buflen, flags)
#    1035                     "non-zero flags not allowed in calls to recv() on %s" %
#    1036                     self.__class__)
# -> 1037             return self.read(buflen)
#    1038         else:
#    1039             return super().recv(buflen, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     911                 return self._sslobj.read(len, buffer)
#     912             else:
# --> 913                 return self._sslobj.read(len)
#     914         except SSLError as x:
#     915             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [raw]
# pyautogui.MINIMUM_DURATION = 0.0
# pyautogui.PAUSE = 0.0
# pyautogui.MINIMUM_SLEEP = 0.0
# while True:
#     for a in range(0, 70):
#         b = int(2 * numpy.sin(a/10))
#         x_shift = b
#         y_shift = b
#         pyautogui.move(x_shift, y_shift)

# %% [raw]
# #the cube control
# from pyquaternion import Quaternion
# from scipy.spatial.transform import Rotation as R
# import numpy
# from math import *
# # from quat import *
# import quaternions
#
# import pygame
# from pygame.locals import *
#
# from OpenGL.GL import *
# from OpenGL.GLU import *
#
# import numpy
#
# def normalize(v, tolerance=0.00001):
#     mag2 = sum(n * n for n in v)
#     if abs(mag2 - 1.0) > tolerance:
#         mag = numpy.sqrt(mag2)
#         v = tuple(n / mag for n in v)
#     return v
#
# def q_mult(q1, q2):
#     w1, x1, y1, z1 = q1
#     w2, x2, y2, z2 = q2
#     w = w1 * w2 - x1 * x2 - y1 * y2 - z1 * z2
#     x = w1 * x2 + x1 * w2 + y1 * z2 - z1 * y2
#     y = w1 * y2 + y1 * w2 + z1 * x2 - x1 * z2
#     z = w1 * z2 + z1 * w2 + x1 * y2 - y1 * x2
#     return w, x, y, z
#
# def q_conjugate(q):
#     w, x, y, z = q
#     return (w, -x, -y, -z)
#
# def qv_mult(q1, v1):
#     q2 = (0.0,) + v1
#     return q_mult(q_mult(q1, q2), q_conjugate(q1))[1:]
#
# def axisangle_to_q(v, theta):
#     v = normalize(v)
#     x, y, z = v
#     theta /= 2
#     w = cos(theta)
#     x = x * sin(theta)
#     y = y * sin(theta)
#     z = z * sin(theta)
#     return w, x, y, z
#
# def q_to_axisangle(q):
#     w, v = q[0], q[1:]
#     theta = acos(w) * 2.0
#     return normalize(v), theta
#
# def q_to_mat4(q):
#     w, x, y, z = q
#     return numpy.array(
#         [[1 - 2*y*y - 2*z*z, 2*x*y - 2*z*w, 2*x*z + 2*y*w, 0],
#         [2*x*y + 2*z*w, 1 - 2*x*x - 2*z*z, 2*y*z - 2*x*w, 0],
#         [2*x*z - 2*y*w, 2*y*z + 2*x*w, 1 - 2*x*x - 2*y*y, 0],
#         [0, 0, 0, 1] ],'f')
#
# axis_verts = (
#     (-7.5, 0.0, 0.0),
#     ( 7.5, 0.0, 0.0),
#     ( 0.0,-7.5, 0.0),
#     ( 0.0, 7.5, 0.0),
#     ( 0.0, 0.0,-7.5),
#     ( 0.0, 0.0, 7.5)
#     )
#
# axes = (
#     (0,1),
#     (2,3),
#     (4,5)
#     )
#
# axis_colors = (
#     (1.0,0.0,0.0), # Red
#     (0.0,1.0,0.0), # Green
#     (0.0,0.0,1.0)  # Blue
#     )
#
#
# '''
#        5____________6
#        /           /|
#       /           / |
#     1/__________2/  |
#     |           |   |
#     |           |   |
#     |           |   7
#     |           |  /
#     |           | /
#     0___________3/
# '''
#
# cube_verts = (
#     (-3.0,-3.0, 3.0),
#     (-3.0, 3.0, 3.0),
#     ( 3.0, 3.0, 3.0),
#     ( 3.0,-3.0, 3.0),
#     (-3.0,-3.0,-3.0),
#     (-3.0, 3.0,-3.0),
#     ( 3.0, 3.0,-3.0),
#     ( 3.0,-3.0,-3.0)
#     )
#
# cube_edges = (
#     (0,1),
#     (0,3),
#     (0,4),
#     (2,1),
#     (2,3),
#     (2,6),
#     (5,1),
#     (5,4),
#     (5,6),
#     (7,3),
#     (7,4),
#     (7,6)
#     )
#
# cube_surfaces = (
#     (0,1,2,3), # Front
#     (3,2,6,7), # Right
#     (7,6,5,4), # Left
#     (4,5,1,0), # Back
#     (1,5,6,2), # Top
#     (4,0,3,7)  # Bottom
#     )
#
# cube_colors = (
#     (0.769,0.118,0.227), # Red
#     (  0.0,0.318,0.729), # Blue
#     (  1.0,0.345,  0.0), # Orange
#     (  0.0, 0.62,0.376), # Green
#     (  1.0,  1.0,  1.0), # White
#     (  1.0,0.835,  0.0)  # Yellow
#     )
#
#
# def Axis():
#     glBegin(GL_LINES)
#     for color,axis in zip(axis_colors,axes):
#         glColor3fv(color)
#         for point in axis:
#             glVertex3fv(axis_verts[point])
#     glEnd()
#
# def Cube():
#     glBegin(GL_QUADS)
#     for color,surface in zip(cube_colors,cube_surfaces):
#         glColor3fv(color)
#         for vertex in surface:
#             glVertex3fv(cube_verts[vertex])
#     glEnd()
#
#     glBegin(GL_LINES)
#     glColor3fv((0.0,0.0,0.0))
#     for edge in cube_edges:
#         for vertex in edge:
#             glVertex3fv(cube_verts[vertex])
#     glEnd()
#
# def main():
#     pygame.init()
#     display = (1280,720)
#     pygame.display.set_mode(display, DOUBLEBUF|OPENGL)
#
#     # Using depth test to make sure closer colors are shown over further ones
#     glEnable(GL_DEPTH_TEST)
#     glDepthFunc(GL_LESS)
#
#     # Default view
#     glMatrixMode(GL_PROJECTION)
#     gluPerspective(45, (display[0]/display[1]), 0.5, 40)
#     glTranslatef(0.0,0.0,-17.5)
#
#
#     inc_x = 0
#     inc_y = 0
#     accum = (1,0,0,0)
#
#     while True:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 pygame.quit()
#                 quit()
#
# #             if event.type == pygame.KEYDOWN:
# #                 #Rotating about the x axis
# #                 if event.key == pygame.K_UP:
# #                     inc_x =  pi/100
# #                 if event.key == pygame.K_DOWN:
# #                     inc_x = -pi/100
#
# #                 # Rotating about the y axis
# #                 if event.key == pygame.K_LEFT:
# #                     inc_y =  pi/100
# #                 if event.key == pygame.K_RIGHT:
# #                     inc_y = -pi/100
#
# #                 # Reset to default view
# #                 if event.key == pygame.K_SPACE:
# #                     accum = (1,0,0,0)
#
# #             if event.type == pygame.KEYUP:
# #                 # Stoping rotation
# #                 if event.key == pygame.K_UP or event.key == pygame.K_DOWN:
# #                     inc_x = 0.0
# #                 if event.key == pygame.K_LEFT or event.key == pygame.K_RIGHT:
# #                     inc_y = 0.0
#
#         gyro_mot = json.loads(receivedData.recv())["mot"]
#
#         rot_x = normalize(axisangle_to_q((1.0,0.0,0.0), inc_x))
#         rot_y = normalize(axisangle_to_q((0.0,1.0,0.0), inc_y))
#         accum = q_mult(accum,rot_x)
#         accum = q_mult(accum,rot_y)
#
#         glMatrixMode(GL_MODELVIEW)
# #         q00,q10,q20,q30 = normalize(gyro_mot[2:6])
# # #         q0,q1,q2,q3 = normalize(gyro_mot[2:6]
# #         #trying to match axis to cube
# #         #this replacement matches axis properly with implementation  rot_mat = angletorotmat(-y_rot, -x_rot, -z_rot)
# #         q0 = q00
# #         q1 = q30
# #         q2 = q10
# #         q3 = q20
#
# #         #trial block: convert quat to euler angle, make rotation matrix to verify
#
# #         y_rot = math.asin( 2*(q0*q2 - q1*q3) )
#
# #         if y_rot == numpy.pi/2:
# #             x_rot = 0
# #             z_rot = -2*math.atan2(q1,q0)
# #         elif y_rot == -numpy.pi/2:
# #             x_rot = 0
# #             z_rot = 2*math.atan2(q1,q0)
# #         else:
# #             x_rot = math.atan2( 2*(q0*q1 + q2*q3), q0**2 - q1**2 - q2**2 + q3**2 )
# #             z_rot = math.atan2( 2*(q0*q3 + q1*q2), q0**2 + q1**2 - q2**2 - q3**2 )
#         x_rot, y_rot, z_rot = quattorotmat(gyro_mot[2:6])
#         rot_mat = angletorotmat(-y_rot, -x_rot, -z_rot)
#         #trial block end
#         glLoadMatrixf(rot_mat)
# #         glLoadMatrixf(q_to_mat4([q0,q1,q2,q3]))
#         glClear(GL_COLOR_BUFFER_BIT|GL_DEPTH_BUFFER_BIT)
#         Cube()
#         Axis()
#         pygame.display.flip()
#         pygame.time.wait(10)
#
# main()
